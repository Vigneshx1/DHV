# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshx1/DHV/blob/main/heat_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.random.random((13,16))
plt.imshow(data,cmap="viridis")
plt.title("2d Heat map")
plt.colorbar()
plt.show()

# %%
data=np.random.random((13,16))
plt.imshow(data,cmap="magma")
plt.title("2d Heat map")
plt.colorbar()
plt.show()

# %%
import seaborn as sns
data=np.random.randint(low=0,high=100,size=(12,12))
hm=sns.heatmap(data=data,annot=True)
plt.show()
