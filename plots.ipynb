# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshx1/DHV/blob/main/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[2,3,4,5]
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("line plot")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,5,6,7]
colors=["r","y","b","g","b"]
sizes=[100,200,300,40,15]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.8,marker="*",edgecolor="g")
plt.title("scatter",fontsize=20)
plt.xlabel("x axis",fontsize=20)
plt.ylabel("y axis",fontsize=20)
plt.show()

# %%
x1=[3,3,4,5,6]
plt.hist(x1,color="r",edgecolor="g",bottom=1,histtype="bar",orientation="vertical",label="python")
plt.axvline(5,color="g")
plt.legend()
plt.show()

# %%
import numpy as np
y=np.array([30,30,40,50])
mylabels = ["apples","bananas","cherries","dates"]
plt.pie(y,labels=mylabels)
plt.show()

# %%
import numpy as np
y=np.array([30,30,40,50])
mylabels = ["apples","bananas","cherries","dates"]
myexplode=[0.2,0.8,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show()

# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")
plt.subplot(2,2,2)
plt.pie([2],colors="r")
plt.subplot(2,2,3)
y=[20,40,50,60]
plt.pie(y)
r=[2,3,4,5]
s=[4,5,6,7]
plt.subplot(2,2,4)
plt.bar(r,s)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
