# %% [markdown]
# <a href="https://colab.research.google.com/github/Vigneshx1/DHV/blob/main/casestudyonbankingsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    'Age_group': ['<21', '21-24','24-27','27-30','30-33','33-36','36-39','57-60','>60'],
    'Totle_no_of_loans': [9,310,511,4000,4568,5698,8209,788,6],
    'No_of_badloans': [2,14,20,172,169,188,197,9,0],
    'NO_of_goodloans': [7,296,491,3828,4399,5510,8012,779,6],
    'Percentage_badloans': ['22%','4.5%','3.9%','4.3%','3.7%','3.3%','2.4%','1.1%','0.0%'],
    'Percentage_goodloans': ['77.8%','95.5%','96.1%','95.7%','96.3%','96.7%','97.6%','98.9%','100%']
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Age_group  Totle_no_of_loans  No_of_badloans  NO_of_goodloans  \
# 0       <21                  9               2                7
# 1     21-24                310              14              296
# 2     24-27                511              20              491
# 3     27-30               4000             172             3828
# 4     30-33               4568             169             4399
# 5     33-36               5698             188             5510
# 6     36-39               8209             197             8012
# 7     57-60                788               9              779
# 8       >60                  6               0                6
#
#   Percentage_badloans Percentage_goodloans
# 0                 22%                77.8%
# 1                4.5%                95.5%
# 2                3.9%                96.1%
# 3                4.3%                95.7%
# 4                3.7%                96.3%
# 5                3.3%                96.7%
# 6                2.4%                97.6%
# 7                1.1%                98.9%
# 8                0.0%                 100%

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Age_group': ['<21', '21-24','24-27','27-30','30-33','33-36','36-39','57-60','>60'],
    'Totle_no_of_loans': [9,310,511,4000,4568,5698,8209,788,6],
    'No_of_badloans': [2,14,20,172,169,188,197,9,0],
    'NO_of_goodloans': [7,296,491,3828,4399,5510,8012,779,6],
    'Percentage_badloans': ['22%','4.5%','3.9%','4.3%','3.7%','3.3%','2.4%','1.1%','0.0%'],
    'Percentage_goodloans': ['77.8%','95.5%','96.1%','95.7%','96.3%','96.7%','97.6%','98.9%','100%']
}

df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))

plt.bar(df['Age_group'], df['No_of_badloans'], color='red', label='Number of Bad Loans')
plt.bar(df['Age_group'], df['NO_of_goodloans'], bottom=df['No_of_badloans'], color='green', label='Number of Good Loans')

plt.xlabel('Age Group')
plt.ylabel('Number of Loans')
plt.title('Number of Loans by Age Group')
plt.legend()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Age_group': ['<21', '21-24','24-27','27-30','30-33','33-36','36-39','57-60','>60'],
    'Totle_no_of_loans': [9,310,511,4000,4568,5698,8209,788,6],
    'No_of_badloans': [2,14,20,172,169,188,197,9,0],
    'NO_of_goodloans': [7,296,491,3828,4399,5510,8012,779,6],
    'Percentage_badloans': ['22%','4.5%','3.9%','4.3%','3.7%','3.3%','2.4%','1.1%','0.0%'],
    'Percentage_goodloans': ['77.8%','95.5%','96.1%','95.7%','96.3%','96.7%','97.6%','98.9%','100%']
}

df = pd.DataFrame(data)

# Plotting Total Number of Loans
plt.figure(figsize=(10, 6))
plt.bar(df['Age_group'], df['Totle_no_of_loans'], color='blue')
plt.xlabel('Age Group')
plt.ylabel('Total Number of Loans')
plt.title('Total Number of Loans by Age Group')
plt.show()

# Plotting Percentage of Bad Loans
plt.figure(figsize=(10, 6))
percent_bad_loans = [float(percent.strip('%')) for percent in df['Percentage_badloans']]
plt.bar(df['Age_group'], percent_bad_loans, color='red')
plt.xlabel('Age Group')
plt.ylabel('Percentage of Bad Loans')
plt.title('Percentage of Bad Loans by Age Group')
plt.show()

# Plotting Percentage of Good Loans
plt.figure(figsize=(10, 6))
percent_good_loans = [float(percent.strip('%')) for percent in df['Percentage_goodloans']]
plt.bar(df['Age_group'], percent_good_loans, color='green')
plt.xlabel('Age Group')
plt.ylabel('Percentage of Good Loans')
plt.title('Percentage of Good Loans by Age Group')
plt.show()
